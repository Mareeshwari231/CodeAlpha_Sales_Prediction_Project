# %% [markdown]
# Sales Prediction Using Python Project

# %% [markdown]
# Importing libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Load the Dataset

# %%
df=pd.read_csv("/content/Advertising.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df=df.drop(columns=['Unnamed: 0'])

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
x=df.iloc[:,0:-1]

# %%
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train
# Out:
#         TV  Radio  Newspaper
# 79   116.0    7.7       23.1
# 197  177.0    9.3        6.4
# 38    43.1   26.7       35.1
# 24    62.3   12.6       18.3
# 122  224.0    2.4       15.6
# ..     ...    ...        ...
# 106   25.0   11.0       29.7
# 14   204.1   32.9       46.0
# 92   217.7   33.5       59.0
# 179  165.6   10.0       17.6
# 102  280.2   10.1       21.4
#
# [160 rows x 3 columns]

# %%
y_train
# Out:
# 79     11.0
# 197    12.8
# 38     10.1
# 24      9.7
# 122    11.6
#        ...
# 106     7.2
# 14     19.0
# 92     19.4
# 179    12.6
# 102    14.8
# Name: Sales, Length: 160, dtype: float64

# %%
x_test
# Out:
#         TV  Radio  Newspaper
# 95   163.3   31.6       52.9
# 15   195.4   47.7       52.9
# 30   292.9   28.3       43.2
# 158   11.7   36.9       45.2
# 128  220.3   49.0        3.2
# 115   75.1   35.0       52.7
# 69   216.8   43.9       27.2
# 170   50.0   11.6       18.4
# 174  222.4    3.4       13.1
# 45   175.1   22.5       31.5
# 66    31.5   24.6        2.2
# 182   56.2    5.7       29.7
# 165  234.5    3.4       84.8
# 78     5.4   29.9        9.4
# 186  139.5    2.1       26.6
# 177  170.2    7.8       35.2
# 56     7.3   28.1       41.4
# 152  197.6   23.3       14.2
# 82    75.3   20.3       32.5
# 68   237.4   27.5       11.0
# 124  229.5   32.3       74.2
# 16    67.8   36.6      114.0
# 148   38.0   40.3       11.9
# 93   250.9   36.5       72.3
# 65    69.0    9.3        0.9
# 60    53.5    2.0       21.4
# 84   213.5   43.0       33.8
# 67   139.3   14.5       10.2
# 125   87.2   11.8       25.9
# 132    8.4   27.2        2.1
# 9    199.8    2.6       21.2
# ...

# %%
y_test
# Out:
# 95     16.9
# 15     22.4
# 30     21.4
# 158     7.3
# 128    24.7
# 115    12.6
# 69     22.3
# 170     8.4
# 174    11.5
# 45     14.9
# 66      9.5
# 182     8.7
# 165    11.9
# 78      5.3
# 186    10.3
# 177    11.7
# 56      5.5
# 152    16.6
# 82     11.3
# 68     18.9
# 124    19.7
# 16     12.5
# 148    10.9
# 93     22.2
# 65      9.3
# 60      8.1
# 84     21.7
# 67     13.4
# 125    10.6
# 132     5.7
# 9      10.6
# 18     11.3
# 55     23.7
# 75      8.7
# 150    16.1
# 104    20.7
# 135    11.6
# 137    20.8
# 164    11.9
# 76      6.9
# Name: Sales, dtype: float64

# %%
x_train=x_train.astype(int)
x_test=x_test.astype(int)
y_train=y_train.astype(int)
y_test=y_test.astype(int)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train_scaled=sc.fit_transform(x_train)
x_test_scaled=sc.fit_transform(x_test)

# %% [markdown]
# Evaluate Performance

# %% [markdown]
# Analyzing data by scatter plot

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred,c='g')

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(x_train_scaled, y_train)


y_pred_rf = rf.predict(x_test_scaled)

r2_rf = r2_score(y_test, y_pred_rf)
mse_rf = mean_squared_error(y_test, y_pred_rf)
mae_rf = mean_absolute_error(y_test, y_pred_rf)


print("\nRandom Forest Model Evaluation:")
print(f"R² Score: {r2_rf:.2f}")
print(f"Mean Squared Error: {mse_rf:.2f}")
print(f"Mean Absolute Error: {mae_rf:.2f}")
# Out:
# Random Forest Model Evaluation:
# R² Score: 0.95
# Mean Squared Error: 1.48
# Mean Absolute Error: 0.96

# %%
# Create Interaction Features
df['TV_Radio'] = df['TV'] * df['Radio']
df['TV_Newspaper'] = df['TV'] * df['Newspaper']

# Update Features
X = df.drop(columns=['Sales'])  # Updated features
y = df['Sales']                # Target

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'lr' is your Linear Regression model
coefficients = pd.DataFrame(lr.coef_, columns=['Coefficients'], index=x.columns)

sns.heatmap(coefficients.T, annot=True, cmap="YlGnBu", fmt=".2f")
plt.title("Feature Coefficients Heatmap")
plt.show()

# %%
corr=df.corr()

# %%
sns.heatmap(corr,annot=True,cmap='summer')
# Out:
# <Axes: >

# %% [markdown]
# Insights:
#
# -Advertising through TV is 78% correlated with sales
#
# -Advertising through Radio is 58% correlated with sales
#
# -Advertising through Newspaper is 23% least correlated with sales

# %%
sns.histplot(data=df,x='Sales',bins=30,kde=True)
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
sns.pairplot(df)

# %%
from sklearn.metrics import r2_score

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor


models = {
    'LinearRegression': LinearRegression(),
    'Lasso': Lasso(),
    'Ridge': Ridge(),
    'RandomForest': RandomForestRegressor(),
}

# %%
def evaluate_model(x_train,y_train,x_test,y_test,models):
  report={}
  for i in range(len(models)):
    model=list(models.values())[i]
    model.fit(x_train,y_train)

    y_pred=model.predict(x_test)

    test_model_score=r2_score(y_test,y_pred)
    report[list(models.keys())[i]]=test_model_score

  return report

# %%
evaluate_model(x_train_scaled,y_train,x_test_scaled,y_test,models)
# Out:
# {'LinearRegression': 0.8811836354878553,
#  'Lasso': 0.7922857250374011,
#  'Ridge': 0.880330730152058,
#  'RandomForest': 0.9522489027212513}

# %% [markdown]
# Insights:
#
# -Random Forest Regressor has the highest accuracy with 95.2%
